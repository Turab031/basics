# %%
print("hello")
# Out:
# hello

# %%
# store all data types
marks =[94.4,87.5,89.78,45.1]
print(marks)
# Out:
# [94.4, 87.5, 89.78, 45.1]

# %%
print(type(marks))
# Out:
# <class 'list'>

# %%
print(marks[0])
# Out:
# 94.4

# %%
# list are mutble
marks[0] = 99.98

print(marks)
# Out:
# [99.98, 87.5, 89.78, 45.1]

# %%
students = ["turab","bob","asma","manazoor"]
print(students)
# Out:
# ['turab', 'bob', 'asma', 'manazoor']

# %%
students[1] = "najaf"
print(students)
# Out:
# ['turab', 'najaf', 'asma', 'manazoor']

# %%
# string are immutble

str = "hello"
print(str)
# Out:
# hello

# %%
# list slicing
# [startindex,lastindex]->last index not included

marks=[85,56,45,34,23,90]

print(marks[0:3])

print(marks[1:])

print(marks[:4])

print(marks[-3:-1])
# Out:
# [85, 56, 45]
# [56, 45, 34, 23, 90]
# [85, 56, 45, 34]
# [34, 23]

# %%
list=[2,3,4,5,6]
list.reverse()
print(list)
# Out:
# [6, 5, 4, 3, 2]

# %%
list.append(78)
print(list)
# Out:
# [6, 5, 4, 3, 2, 78]

# %%
list.sort(reverse=True)
print(list)
# Out:
# [78, 6, 5, 4, 3, 2]

# %%
list.insert(4,89)
print(list)
# Out:
# [78, 6, 5, 4, 89, 3, 2]

# %%
list.remove(6)
print(list)
# Out:
# [78, 5, 4, 89, 3, 2]

# %%
list.pop(3)
print(list)
# Out:
# [78, 5, 4, 3, 2]
