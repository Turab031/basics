# %%
tup = (2,1,4,5,6,8,2,2,2)
num = tup.count(2)
print(num)
# Out:
# 4

# %%
movies = []
mov = input("enter 1st movie")
mov2 = input("enter 1st movie")
mov3 = input("enter 1st movie")


movies.append(mov)
movies.append(mov2)
movies.append(mov3)
