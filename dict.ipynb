# %%
info ={
    "key":"value",
    "name":"ac",
    "age":35,
    "marks":94.5,
    "is_Adult":True
}

print(info)
print(info["age"])
info["name"]="turab",

print(info)

info["naya_key"]="ha theek hai"

print(info)
# Out:
# {'key': 'value', 'name': 'ac', 'age': 35, 'marks': 94.5, 'is_Adult': True}
# 35
# {'key': 'value', 'name': ('turab',), 'age': 35, 'marks': 94.5, 'is_Adult': True}
# {'key': 'value', 'name': ('turab',), 'age': 35, 'marks': 94.5, 'is_Adult': True, 'naya_key': 'ha theek hai'}

# %%
print("hello")
# Out:
# hello

# %%
dict ={
    "subjects":["python","c++","java"],
    "topics":("dict","set")

}
print(dict)
# Out:
# {'subjects': ['python', 'c++', 'java'], 'topics': ('dict', 'set')}

# %%
student={
    "name":"najaf",
    "subject":{
        "phy":89,
        "chem":92,
        "maths":"92"
    }
}

print(student)

print(student["subject"]["chem"])
print(student.keys())

print(student.values())

print(student.items())

print(student["name"])
print(student.get("name"))
# Out:
# {'name': 'najaf', 'subject': {'phy': 89, 'chem': 92, 'maths': '92'}}
# 92
# dict_keys(['name', 'subject'])
# dict_values(['najaf', {'phy': 89, 'chem': 92, 'maths': '92'}])
# dict_items([('name', 'najaf'), ('subject', {'phy': 89, 'chem': 92, 'maths': '92'})])
# najaf
# najaf
