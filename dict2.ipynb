# %%
info ={
    "key":"value",
    "name":"ac",
    "age":35,
    "marks":94.5,
    "is_Adult":True
}

new_dict={"city":"delhi"}
info.update(new_dict)
print(info)
# Out:
# {'key': 'value', 'name': 'ac', 'age': 35, 'marks': 94.5, 'is_Adult': True, 'city': 'delhi'}
